# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("..\Dataset\house_price_data.csv")
df_data = pd.DataFrame(data)
df_data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\shs78\AppData\Local\Temp\ipykernel_10196\2907776697.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data = pd.read_csv("..\Dataset\house_price_data.csv")
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# ...

# %%
df_data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df_data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df_data.nunique()
# Out:
# date               70
# price            1741
# bedrooms           10
# bathrooms          26
# sqft_living       566
# sqft_lot         3113
# floors              6
# waterfront          2
# view                5
# condition           5
# sqft_above        511
# sqft_basement     207
# yr_built          115
# yr_renovated       60
# street           4525
# city               44
# statezip           77
# country             1
# dtype: int64

# %%
unwanted_col = ['date','yr_renovated','street','city','statezip','country']
df_data = df_data.drop(unwanted_col,axis=1)
df_data
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built
# ...

# %%
df_corr = df_data.corr()
plt.figure(figsize=(15,8))
sns.heatmap(df_corr,annot=True,cmap="coolwarm")
plt.show()

# %%
import scipy.stats as stats

z_score = stats.zscore(df_data)
threshold = 3

print("size before removing outliers",df_data.shape)
outliers_df = df_data[(threshold < z_score).any(axis=1)]
df_data = df_data[(threshold >= z_score).all(axis=1)]
print("size after removing outliers",df_data.shape)
# Out:
# size before removing outliers (4600, 12)
# size after removing outliers (4244, 12)

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
scale.fit(df_data)
df_scaled = pd.DataFrame(scale.transform(df_data),columns=df_data.columns)

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
x = df_data.drop('price',axis=1)
y = df_data['price']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
models = [
    ('DecisionTreeRegressor',DecisionTreeRegressor()),
    ('KNeighborsRegressor',KNeighborsRegressor()),
    ('RandomForestRegressor',RandomForestRegressor()),
    ('LinearRegression',LinearRegression())
]

for name,model in models:
    model = model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    print(name)
    print("mean_absolute_error",mean_absolute_error(y_test,y_pred))
    print("mean_squared_error",mean_squared_error(y_test,y_pred))
    print("r2_score",r2_score(y_test,y_pred))
    print("")
# Out:
# DecisionTreeRegressor
# mean_absolute_error 185358.92066493025
# mean_squared_error 73611455980.72688
# r2_score 0.013033127926984744
#
# KNeighborsRegressor
# mean_absolute_error 155957.7490738805
# mean_squared_error 54270710864.73361
# r2_score 0.2723497581494757
#
# RandomForestRegressor
# mean_absolute_error 141226.13773764562
# mean_squared_error 43634434654.025345
# r2_score 0.4149587056607962
#
# LinearRegression
# mean_absolute_error 139590.95600748347
# mean_squared_error 41194072741.057686
# r2_score 0.44767856334977363

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}

# %%
rf = RandomForestRegressor(random_state=42)
random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_grid,
                                   n_iter=50, cv=5, verbose=2, random_state=42,
                                   n_jobs=-1, scoring='neg_mean_squared_error')

random_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# c:\Users\shs78\Desktop\Gen_AI_Project\myenv\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 115 fits failed out of a total of 250.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 70 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\shs78\Desktop\Gen_AI_Project\myenv\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\shs78\Desktop\Gen_AI_Project\myenv\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
# ...

# %%
import numpy as np

best_model = random_search.best_estimator_ 

y_pred = best_model.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("Best Parameters:", random_search.best_params_)
print("Test RMSE:", rmse)
# Out:
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
# Test RMSE: 203019.77933511924
